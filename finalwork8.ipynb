# %%
import pandas as pd
import numpy as np

# %%
customers_df=pd.read_csv (r"C:\Data Analusis Course\wk8\wk8-customers.csv")
products_df = pd.read_csv(r"C:\Data Analusis Course\wk8\wk8-products.csv")
stores_df =pd.read_csv(r"C:\Data Analusis Course\wk8\wk8-stores.csv")
sales_df =pd.read_csv(r"C:\Data Analusis Course\wk8\wk8-sales.csv")
inventory_df =pd.read_csv(r"C:\Data Analusis Course\wk8\wk8-inventory.csv")

# %%
print(customers_df.head(), "\n")
print(products_df.head(), "\n")
print(stores_df.head(), "\n")
print(sales_df.head(), "\n")
print(inventory_df.head(), "\n")
# Out:
#    customer_id first_name last_name                  email           phone  \
# 0            1      James     Smith  james.smith@gmail.com    555-123-4567
# 1            2       Mary   Johnson                    NaN    212.555.6789
# 2            3       John  Williams    jwilliams@yahoo.com  (555) 987-6543
# 3            4   Patricia     Brown     pbrown@hotmail.com      5551234567
# 4            5     Robert     Jones     rjones23@gmail.com    555-987-3456
#
#         address         city       state    zip_code registration_date
# 0   123 Main St     New York          NY       10001         3/15/2021
# 1  456 Park Ave     New York          NY       10022         11/2/2020
# 2  789 Broadway  Los Angeles  California  90001-1234         5/20/2021
# 3    321 Elm St      Chicago          IL       60601               NaN
# 4   555 Pine St      Houston          TX       77002         9/12/2020
#
#    product_id        product_name     category  subcategory    brand    price  \
# ...

# %%
print(customers_df.info(), "\n")
print(customers_df.describe(), "\n")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        31 non-null     int64
#  1   first_name         31 non-null     str
#  2   last_name          31 non-null     str
#  3   email              28 non-null     str
#  4   phone              29 non-null     str
#  5   address            31 non-null     str
#  6   city               31 non-null     str
#  7   state              31 non-null     str
#  8   zip_code           30 non-null     str
#  9   registration_date  28 non-null     str
# dtypes: int64(1), str(9)
# memory usage: 5.0 KB
# None
#
#        customer_id
# count    31.000000
# mean     15.838710
# std       8.858505
# min       1.000000
# 25%       8.500000
# 50%      16.000000
# 75%      23.500000
# max      30.000000

# %%
print(products_df.info(), "\n")
print(products_df.describe(), "\n")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    30 non-null     int64
#  1   product_name  30 non-null     str
#  2   category      30 non-null     str
#  3   subcategory   30 non-null     str
#  4   brand         30 non-null     str
#  5   price         30 non-null     float64
#  6   cost          30 non-null     float64
#  7   weight        28 non-null     float64
# dtypes: float64(3), int64(1), str(4)
# memory usage: 3.3 KB
# None
#
#        product_id        price         cost     weight
# count   30.000000    30.000000    30.000000  28.000000
# mean    15.500000   191.724000   203.159000   3.835714
# std      8.803408   452.483576   278.924138   5.693236
# min      1.000000 -1599.990000     1.800000   0.200000
# 25%      8.250000    46.990000    28.375000   0.500000
# 50%     15.500000   134.990000    82.500000   1.150000
# ...

# %%
print(stores_df.info(), "\n")
print(stores_df.describe(), "\n")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   store_id      15 non-null     int64
#  1   store_name    15 non-null     str
#  2   address       15 non-null     str
#  3   city          15 non-null     str
#  4   state         15 non-null     str
#  5   zip_code      15 non-null     str
#  6   region        15 non-null     str
#  7   size_sqft     13 non-null     float64
#  8   opening_date  14 non-null     str
# dtypes: float64(1), int64(1), str(7)
# memory usage: 2.1 KB
# None
#
#         store_id     size_sqft
# count  15.000000     13.000000
# mean    8.000000  30653.846154
# std     4.472136  11342.002717
# min     1.000000  16500.000000
# 25%     4.500000  22000.000000
# 50%     8.000000  29000.000000
# 75%    11.500000  35000.000000
# max    15.000000  55000.000000

# %%
print(sales_df.info(), "\n")
print(sales_df.describe(), "\n")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sale_id         40 non-null     int64
#  1   date            39 non-null     str
#  2   store_id        39 non-null     float64
#  3   customer_id     40 non-null     int64
#  4   product_id      40 non-null     int64
#  5   quantity        40 non-null     int64
#  6   total           40 non-null     float64
#  7   payment_method  39 non-null     str
# dtypes: float64(2), int64(4), str(2)
# memory usage: 3.3 KB
# None
#
#          sale_id   store_id  customer_id  product_id   quantity        total
# count  40.000000  39.000000    40.000000   40.000000  40.000000    40.000000
# mean   20.500000   6.487179    14.075000   13.500000   1.625000   352.296500
# std    11.690452   4.235637     8.303189    8.857852   0.952392   377.625776
# ...

# %%
print(inventory_df.info(), "\n")
print(inventory_df.describe(), "\n")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   inventory_id       75 non-null     int64
#  1   store_id           75 non-null     int64
#  2   product_id         75 non-null     int64
#  3   quantity_in_stock  75 non-null     int64
#  4   last_restock_date  66 non-null     str
#  5   reorder_level      69 non-null     float64
# dtypes: float64(1), int64(4), str(1)
# memory usage: 4.3 KB
# None
#
#        inventory_id   store_id  product_id  quantity_in_stock  reorder_level
# count     75.000000  75.000000   75.000000          75.000000      69.000000
# mean      38.000000   8.000000   12.733333          22.640000      12.681159
# std       21.794495   4.349588    7.179801          13.923187       3.327659
# min        1.000000   1.000000    1.000000           0.000000       8.000000
# ...

# %%
customers_df.isnull().sum()
# Out:
# customer_id          0
# first_name           0
# last_name            0
# email                3
# phone                2
# address              0
# city                 0
# state                0
# zip_code             1
# registration_date    3
# dtype: int64

# %%
products_df.isnull().sum()
# Out:
# product_id      0
# product_name    0
# category        0
# subcategory     0
# brand           0
# price           0
# cost            0
# weight          2
# dtype: int64

# %%
stores_df.isnull().sum()
# Out:
# store_id        0
# store_name      0
# address         0
# city            0
# state           0
# zip_code        0
# region          0
# size_sqft       2
# opening_date    1
# dtype: int64

# %%
sales_df.isnull().sum()
# Out:
# sale_id           0
# date              1
# store_id          1
# customer_id       0
# product_id        0
# quantity          0
# total             0
# payment_method    1
# dtype: int64

# %%
inventory_df.isnull().sum()
# Out:
# inventory_id         0
# store_id             0
# product_id           0
# quantity_in_stock    0
# last_restock_date    9
# reorder_level        6
# dtype: int64

# %%
customers_df.dtypes
# Out:
# customer_id          int64
# first_name             str
# last_name              str
# email                  str
# phone                  str
# address                str
# city                   str
# state                  str
# zip_code               str
# registration_date      str
# dtype: object

# %%
products_df.dtypes
# Out:
# product_id        int64
# product_name        str
# category            str
# subcategory         str
# brand               str
# price           float64
# cost            float64
# weight          float64
# dtype: object

# %%
stores_df.dtypes
# Out:
# store_id          int64
# store_name          str
# address             str
# city                str
# state               str
# zip_code            str
# region              str
# size_sqft       float64
# opening_date        str
# dtype: object

# %%
stores_df.dtypes
# Out:
# store_id          int64
# store_name          str
# address             str
# city                str
# state               str
# zip_code            str
# region              str
# size_sqft       float64
# opening_date        str
# dtype: object

# %%
inventory_df.dtypes
# Out:
# inventory_id           int64
# store_id               int64
# product_id             int64
# quantity_in_stock      int64
# last_restock_date        str
# reorder_level        float64
# dtype: object

# %%
p=products_df['product_name'].unique()

# %%
print(p)
#How many unique products are in the product catalog?
print('there is', len(p),'unique products')
# Out:
# <ArrowStringArray>
# [               'Apple iPhone 13',             'Samsung Galaxy S21',
#                 'Sony WH-1000XM4',                    'Dell XPS 13',
#                'Nike Classic Tee',              'Levi's Slim Jeans',
#          'KitchenAid Stand Mixer',         'Cuisinart Coffee Maker',
#               'IKEA Malm Dresser',    'Penguin Classics Collection',
#           'The North Face Jacket',             'Nike Running Shoes',
#              'LEGO Star Wars Set',       'L'Oreal Revitalift Cream',
#               'Apple MacBook Pro',           'Bose QuietComfort 45',
#  'Hershey's Chocolate Assortment',             'Adidas Track Pants',
#               'Kindle Paperwhite',               'Dyson V11 Vacuum',
#               'Outdoor Gas Grill',       'Calvin Klein Men's Shirt',
#            'Coleman Camping Tent',       'Mattel Barbie Dreamhouse',
#            'Neutrogena Face Wash',           'General Mills Cereal',
# ...

# %%
#top 5 most expensive products
products_df.sort_values(by='price', ascending=False).head(5)
# Out:
#     product_id        product_name        category  subcategory    brand  \
# 3            4         Dell XPS 13     Electronics      Laptops     Dell
# 0            1     Apple iPhone 13     Electronics  Smartphones    Apple
# 1            2  Samsung Galaxy S21     electronics  Smartphones  Samsung
# 19          20    Dyson V11 Vacuum  HOME & KITCHEN   Appliances    Dyson
# 26          27  Sony PlayStation 5     Electronics       Gaming     Sony
#
#       price    cost  weight
# 3   1299.99  899.99    2.80
# 0    899.99  649.99    0.45
# 1    799.99  539.99    0.50
# 19   599.99  375.00    6.70
# 26   499.99  399.00    4.50

# %%
#Which store has the largest floor space?
largest_store=stores_df.sort_values('size_sqft', ascending=False).head(1)
print('largest  store is',largest_store['store_name'])
# Out:
# largest  store is 2    Los Angeles Plaza
# Name: store_name, dtype: str

# %%
#What is the distribution of customers by state?
customer_counts = customers_df['state'].value_counts()
print(customer_counts)
# Out:
# state
# TX                4
# CA                3
# NY                2
# California        1
# IL                1
# AZ                1
# PA                1
# Texas             1
# FL                1
# OH                1
# North Carolina    1
# IN                1
# Washington        1
# CO                1
# MA                1
# Oregon            1
# NV                1
# MI                1
# TN                1
# Maryland          1
# MD                1
# KY                1
# WI                1
# NM                1
# MO                1
# Name: count, dtype: int64

# %%
customers_df.isnull().sum()
# Out:
# customer_id          0
# first_name           0
# last_name            0
# email                3
# phone                2
# address              0
# city                 0
# state                0
# zip_code             1
# registration_date    3
# dtype: int64

# %%
customers_df['registration_date']=customers_df['registration_date'].bfill

# %%
print(customers_df.isnull().sum())
print("I didn't fill email, phone number and zip code with any thing because I think  this will miss the data, I replaced the registration date with previous date")
# Out:
# customer_id          0
# first_name           0
# last_name            0
# email                3
# phone                2
# address              0
# city                 0
# state                0
# zip_code             1
# registration_date    0
# dtype: int64
# I didn't fill email, phone number and zip code with any thing because I think  this will miss the data, I replaced the registration date with previous date

# %%
products_df.isnull().sum()
# Out:
# product_id      0
# product_name    0
# category        0
# subcategory     0
# brand           0
# price           0
# cost            0
# weight          2
# dtype: int64

# %%
products_df['weight']=products_df['weight'].fillna(products_df['weight'].mean())

# %%
print(products_df.isnull().sum())
print("====================================","\n")
print("There is No null Values Now in Products")
# Out:
# product_id      0
# product_name    0
# category        0
# subcategory     0
# brand           0
# price           0
# cost            0
# weight          0
# dtype: int64
# ...
#
# There is No null Values Now in Products

# %%
stores_df.isnull().sum()
# Out:
# store_id        0
# store_name      0
# address         0
# city            0
# state           0
# zip_code        0
# region          0
# size_sqft       2
# opening_date    1
# dtype: int64

# %%
stores_df['size_sqft']=stores_df['size_sqft'].fillna(stores_df['size_sqft'].mean())

# %%
stores_df['opening_date']=stores_df['opening_date'].bfill()

# %%
stores_df.isnull().sum()
print(stores_df.isnull().sum())
print('=================================')
print("Stores has No Missing Values Now")
# Out:
# store_id        0
# store_name      0
# address         0
# city            0
# state           0
# zip_code        0
# region          0
# size_sqft       0
# opening_date    0
# dtype: int64
# ...
# Stores has No Missing Values Now

# %%
sales_df.isnull().sum()
# Out:
# sale_id           0
# date              1
# store_id          1
# customer_id       0
# product_id        0
# quantity          0
# total             0
# payment_method    1
# dtype: int64

# %%
sales_df['date']=sales_df['date'].bfill

# %%
sales_df['payment_method']=sales_df['payment_method'].bfill

# %%
sales_df['store_id']=sales_df['store_id'].bfill

# %%
print(sales_df.isnull().sum())
print('=================================','\n')
print('No Null Values in Sales Now')
# Out:
# sale_id           0
# date              0
# store_id          0
# customer_id       0
# product_id        0
# quantity          0
# total             0
# payment_method    0
# dtype: int64
# ...
#
# No Null Values in Sales Now

# %%
inventory_df.isnull().sum()
# Out:
# inventory_id         0
# store_id             0
# product_id           0
# quantity_in_stock    0
# last_restock_date    9
# reorder_level        6
# dtype: int64

# %%
inventory_df['reorder_level'].mode()
# Out:
# 0    10.0
# Name: reorder_level, dtype: float64

# %%
inventory_df['last_restock_date']=inventory_df['last_restock_date'].ffill()

# %%
inventory_df['reorder_level']=inventory_df['reorder_level'].fillna(10)

# %%
print(inventory_df.isnull().sum())
print("===============================","\n")
print("No null Values in Inventory Now")
# Out:
# inventory_id         0
# store_id             0
# product_id           0
# quantity_in_stock    0
# last_restock_date    0
# reorder_level        0
# dtype: int64
# ...
#
# No null Values in Inventory Now

# %%
customers_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# dtype: bool

# %%
#I will remove the duplicate if the firt and last name and city are the same
# and there is one (26 is true)
customers_df[['first_name','last_name','city']].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# dtype: bool

# %%
customers_df[['first_name','last_name','city']].drop_duplicates(keep='first')
#it is the same customer but depending on other information like the phone or state didn't help because the information written in a different way,so looking at first and last name and city helped make sure it is the same person so it duplicated
# Out:
#      first_name  last_name           city
# 0         James      Smith       New York
# 1          Mary    Johnson       New York
# 2          John   Williams    Los Angeles
# 3      Patricia      Brown        Chicago
# 4        Robert      Jones        Houston
# 5      Jennifer     Miller        Phoenix
# 6       Michael      Davis   Philadelphia
# 7         Linda     Garcia    San Antonio
# 8       William  Rodriguez      San Diego
# 9     Elizabeth     Wilson         Dallas
# 10        David   Martinez       San Jose
# 11      Barbara   Anderson         Austin
# 12      Richard     Taylor   Jacksonville
# 13        Susan     Thomas     Fort Worth
# 14       Joseph  Hernandez       Columbus
# 15      Jessica      Moore      Charlotte
# 16       Thomas     Martin  San Francisco
# 17        Sarah    Jackson   Indianapolis
# 18      Charles   Thompson        Seattle
# 19        Karen      White         Denver
# 20  Christopher      Lopez         Boston
# ...

# %%
customers_df=customers_df.drop(26)

# %%
customers_df
# Out:
#     customer_id   first_name  last_name                   email  \
# 0             1        James      Smith   james.smith@gmail.com
# 1             2         Mary    Johnson                     NaN
# 2             3         John   Williams     jwilliams@yahoo.com
# 3             4     Patricia      Brown      pbrown@hotmail.com
# 4             5       Robert      Jones      rjones23@gmail.com
# 5             6     Jennifer     Miller     jmiller@outlook.com
# 6             7      Michael      Davis        mdavis@gmail.com
# 7             8        Linda     Garcia       lgarcia@yahoo.com
# 8             9      William  Rodriguez  wrodriguez@hotmail.com
# 9            10    Elizabeth     Wilson       ewilson@gmail.com
# 10           11        David   Martinez     dmartinez@yahoo.com
# 11           12      Barbara   Anderson                     NaN
# 12           13      Richard     Taylor     rtaylor@outlook.com
# 13           14        Susan     Thomas     sthomas45@gmail.com
# ...

# %%
#Discussion Questions

# %%
#Key Advantages of Using PandasSpeed:
1-Processes millions of rows instantly by handling entire columns at once.Simplicity:
2-Replaces manual Excel work with short, reusable commands.
3-Flexibility: Merges, reshapes, and filters messy data with minimal code
4-Connections: Links perfectly with graphing tools .

# %%
#2. Handling Pattern-Based Missing Data If data is missing for a specific reason, standard averages can fill the results.
filling: Fill missing fields using the average of a specific, relevant group. 
flags: Add a column tracking what was missing to preserve that pattern

# %%
# What types of data quality issues might not be immediately visible through simple DataFrame inspection methods?
Hidden spaces:like "USA " and "USA" look identical but cause matching errors.
Fake text: Placeholder entries like "N/A", "None", or -999 that trick the computer into thinking data is there.
Bad logic: Impossible combinations, like a checkout date that happens before the check-in date.

# %%
#4 How would you document your data cleaning process to ensure reproducibility?
# I wrote notes in my jypyter note work and i wrote these to my personal notes

# %%
#In what scenarios might it be better to remove rows with missing values rather than imputing them?
The row is missing almost all of its information anyway
 The exact answer you are trying to predict is blank.
